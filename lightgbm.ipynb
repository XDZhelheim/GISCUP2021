# %%
import numpy as np
import pandas as pd
import json
import pickle
from sklearn.metrics import f1_score
import lightgbm as lgb
from sklearn.model_selection import KFold,train_test_split
from sklearn.metrics import roc_curve
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt

pd.set_option('display.max_rows',200)

# %%
train = pd.read_csv('/media/fan/hdd/giscup/train.csv')
test = pd.read_csv('/media/fan/hdd/giscup/test.csv')

# %%
# test = pd.read_csv('/media/fan/hdd/giscup/test.csv')
test['date'] = '20200901'
train['date'] = pd.to_datetime(train['date'].astype('str'))
test['date'] = pd.to_datetime(test['date'])

# %%
for df in [train,test]:
    df['day_bias'] = (df['date']-pd.Timestamp(2020,8,1)).dt.days
    df['weekday'] = df['date'].dt.weekday<5
    df['cross_no'] = df['cross_no']*(df['cross_sum']>0)
    df['link_length'] = df['distance']/df['link_no']
    df['log_distance'] = np.log(df['distance'])
    df['log_simple_eta'] = np.log(df['simple_eta'])
    
    for i in range(5):
        df['current_no_ratio_'+str(i)] = df['current_no_'+str(i)]/df['link_no']
        df['current_time_ratio_'+str(i)] = df['current_time_sum_'+str(i)]/(df['simple_eta']-df['cross_sum'])
        df['next_no_ratio_'+str(i)] = df['next_no_'+str(i)]/df['link_no']
        df['next_time_ratio_'+str(i)] = df['next_time_sum_'+str(i)]/(df['simple_eta']-df['cross_sum'])
    for i in range(4):
        df['type_no_ratio_'+str(i)] = df['type_no_'+str(i)]/df['link_no']
        df['type_time_ratio_'+str(i)] = df['type_time_sum_'+str(i)]/(df['simple_eta']-df['cross_sum'])

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df
train = reduce_mem_usage(train)
# Out:
# Memory usage after optimization is: 1856.30 MB
# Decreased by 73.7%

# %%
num_cols = [x for x in train.columns if x not in ['order_id', 'ata','date', 'driver_id',
                                                  'arrival_0','arrival_1','arrival_2','arrival_3','arrival_4']]
cat_cols = []
features = num_cols+cat_cols
train_x = train[features]
test_x = test[features]
train_y = np.log(train['ata'])
print(len(features),features)
# Out:
# 104 ['slice_id', 'distance', 'simple_eta', 'speed', 'speed_avg', 'speed_std', 'speed_min', 'speed_max', 'volume', 'old_driver', 'link_no', 'link_time_sum', 'link_time_avg', 'link_time_std', 'link_time_max', 'link_time_min', 'link_no_0', 'link_no_1', 'link_no_2', 'link_no_3', 'link_no_4', 'link_time_sum_0', 'link_time_sum_1', 'link_time_sum_2', 'link_time_sum_3', 'link_time_sum_4', 'link_time_avg_0', 'link_time_avg_1', 'link_time_avg_2', 'link_time_avg_3', 'link_time_avg_4', 'link_time_std_0', 'link_time_std_1', 'link_time_std_2', 'link_time_std_3', 'link_time_std_4', 'link_time_max_0', 'link_time_max_1', 'link_time_max_2', 'link_time_max_3', 'link_time_max_4', 'link_time_min_0', 'link_time_min_1', 'link_time_min_2', 'link_time_min_3', 'link_time_min_4', 'next_no_1.0', 'next_no_2.0', 'next_no_3.0', 'next_no_4.0', 'next_time_sum_1.0', 'next_time_sum_2.0', 'next_time_sum_3.0', 'next_time_sum_4.0', 'next_time_avg_1.0', 'next_time_avg_2.0', 'next_time_avg_3.0', 'next_time_avg_4.0', 'next_time_std_1.0', 'next_time_std_2.0', 'next_time_std_3.0', 'next_time_std_4.0', 'next_time_max_1.0', 'next_time_max_2.0', 'next_time_max_3.0', 'next_time_max_4.0', 'next_time_min_1.0', 'next_time_min_2.0', 'next_time_min_3.0', 'next_time_min_4.0', 'cross_no', 'cross_sum', 'cross_avg', 'cross_std', 'cross_max', 'cross_min', 'link_status_no_0', 'link_status_no_1', 'link_status_no_2', 'link_status_no_3', 'link_status_no_4', 'day_bias', 'weekday', 'link_length', 'log_distance', 'log_simple_eta', 'link_ratio_0', 'link_time_ratio_0', 'link_ratio_1', 'link_time_ratio_1', 'link_ratio_2', 'link_time_ratio_2', 'link_ratio_3', 'link_time_ratio_3', 'link_ratio_4', 'link_time_ratio_4', 'next_ratio_1', 'next_time_ratio_1', 'next_ratio_2', 'next_time_ratio_2', 'next_ratio_3', 'next_time_ratio_3', 'next_ratio_4', 'next_time_ratio_4']

# %%
     
lgb_paras = {
    'objective': 'regression',
    'metrics': 'rmse',
    'learning_rate': 0.1,
#     'num_leaves': 100,
    'max_depth': -1,
    'lambda_l1': 0.01,
    'lambda_l2': 0.02,
    'seed': 416,
    'feature_fraction': 1,
    'bagging_fraction': 0.8,
    'boost_from_average':'false',
    'bagging_freq': 3,
    'num_threads': 6,

    'verbose':-1,
    'device': 'gpu'
}

# %%
days = train['date'].unique()
tr_days,val_days = train_test_split(days,test_size=0.2,random_state=416)
tr_x = train_x[train['date'].isin(tr_days)]
tr_y = train_y[train['date'].isin(tr_days)]
val_x = train_x[train['date'].isin(val_days)]
val_y = train_y[train['date'].isin(val_days)]
# tr_x, val_x, tr_y, val_y = train_test_split(train_x,train_y,test_size=0.2,random_state=416)
train_set = lgb.Dataset(tr_x, tr_y,categorical_feature=cat_cols)
val_set = lgb.Dataset(val_x, val_y,categorical_feature=cat_cols)
lgb_model = lgb.train(lgb_paras, train_set, categorical_feature=cat_cols,
                      valid_sets=[train_set,val_set], early_stopping_rounds=100, num_boost_round=1000, verbose_eval=100)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.18499	valid_1's rmse: 0.18308
# [200]	training's rmse: 0.183645	valid_1's rmse: 0.181972
# [300]	training's rmse: 0.182984	valid_1's rmse: 0.181553
# [400]	training's rmse: 0.182523	valid_1's rmse: 0.181268
# [500]	training's rmse: 0.182152	valid_1's rmse: 0.181094
# [600]	training's rmse: 0.181816	valid_1's rmse: 0.180936
# [700]	training's rmse: 0.181519	valid_1's rmse: 0.180819
# [800]	training's rmse: 0.181239	valid_1's rmse: 0.180719
# [900]	training's rmse: 0.180972	valid_1's rmse: 0.180623
# [1000]	training's rmse: 0.180701	valid_1's rmse: 0.180501
# [1100]	training's rmse: 0.180455	valid_1's rmse: 0.180431
# [1200]	training's rmse: 0.180232	valid_1's rmse: 0.180361
# [1300]	training's rmse: 0.180006	valid_1's rmse: 0.180295
# [1400]	training's rmse: 0.179789	valid_1's rmse: 0.180236
# [1500]	training's rmse: 0.179582	valid_1's rmse: 0.180187
# [1600]	training's rmse: 0.179394	valid_1's rmse: 0.180144
# [1700]	training's rmse: 0.179197	valid_1's rmse: 0.180092
# [1800]	training's rmse: 0.179009	valid_1's rmse: 0.180054
# [1900]	training's rmse: 0.178827	valid_1's rmse: 0.180016
# [2000]	training's rmse: 0.178637	valid_1's rmse: 0.179966
# [2100]	training's rmse: 0.178462	valid_1's rmse: 0.17993
# [2200]	training's rmse: 0.178297	valid_1's rmse: 0.179904
# [2300]	training's rmse: 0.178129	valid_1's rmse: 0.17987
# [2400]	training's rmse: 0.177959	valid_1's rmse: 0.179836
# [2500]	training's rmse: 0.177788	valid_1's rmse: 0.179794
# [2600]	training's rmse: 0.177624	valid_1's rmse: 0.179763
# [2700]	training's rmse: 0.177463	valid_1's rmse: 0.179729
# [2800]	training's rmse: 0.177311	valid_1's rmse: 0.179704
# [2900]	training's rmse: 0.177155	valid_1's rmse: 0.179679
# [3000]	training's rmse: 0.177005	valid_1's rmse: 0.17966
# [3100]	training's rmse: 0.176846	valid_1's rmse: 0.179629
# [3200]	training's rmse: 0.176697	valid_1's rmse: 0.179604
# [3300]	training's rmse: 0.176554	valid_1's rmse: 0.17959
# [3400]	training's rmse: 0.176397	valid_1's rmse: 0.179563
# [3500]	training's rmse: 0.176253	valid_1's rmse: 0.179541
# [3600]	training's rmse: 0.176113	valid_1's rmse: 0.179522
# [3700]	training's rmse: 0.175973	valid_1's rmse: 0.179504
# [3800]	training's rmse: 0.175829	valid_1's rmse: 0.179482
# [3900]	training's rmse: 0.175686	valid_1's rmse: 0.179466
# [4000]	training's rmse: 0.175548	valid_1's rmse: 0.179447
# [4100]	training's rmse: 0.175413	valid_1's rmse: 0.179432
# [4200]	training's rmse: 0.175277	valid_1's rmse: 0.179412
# [4300]	training's rmse: 0.175147	valid_1's rmse: 0.1794
# [4400]	training's rmse: 0.175015	valid_1's rmse: 0.179386
# [4500]	training's rmse: 0.174884	valid_1's rmse: 0.179368
# [4600]	training's rmse: 0.17476	valid_1's rmse: 0.179356
# [4700]	training's rmse: 0.174626	valid_1's rmse: 0.179337
# [4800]	training's rmse: 0.1745	valid_1's rmse: 0.179325
# [4900]	training's rmse: 0.174377	valid_1's rmse: 0.179312
# [5000]	training's rmse: 0.174248	valid_1's rmse: 0.179296
# [5100]	training's rmse: 0.174118	valid_1's rmse: 0.179284
# [5200]	training's rmse: 0.173992	valid_1's rmse: 0.17928
# [5300]	training's rmse: 0.173867	valid_1's rmse: 0.179265
# [5400]	training's rmse: 0.173738	valid_1's rmse: 0.179248
# [5500]	training's rmse: 0.17362	valid_1's rmse: 0.17924
# [5600]	training's rmse: 0.173493	valid_1's rmse: 0.179226
# [5700]	training's rmse: 0.173374	valid_1's rmse: 0.179219
# [5800]	training's rmse: 0.173253	valid_1's rmse: 0.179208
# [5900]	training's rmse: 0.173137	valid_1's rmse: 0.1792
# [6000]	training's rmse: 0.17302	valid_1's rmse: 0.17919
# [6100]	training's rmse: 0.172905	valid_1's rmse: 0.179186
# [6200]	training's rmse: 0.172792	valid_1's rmse: 0.179182
# [6300]	training's rmse: 0.172676	valid_1's rmse: 0.179172
# [6400]	training's rmse: 0.172559	valid_1's rmse: 0.179162
# [6500]	training's rmse: 0.172449	valid_1's rmse: 0.179157
# [6600]	training's rmse: 0.172337	valid_1's rmse: 0.179148
# [6700]	training's rmse: 0.172228	valid_1's rmse: 0.179139
# [6800]	training's rmse: 0.17212	valid_1's rmse: 0.179128
# [6900]	training's rmse: 0.172009	valid_1's rmse: 0.179119
# [7000]	training's rmse: 0.171897	valid_1's rmse: 0.179107
# [7100]	training's rmse: 0.171785	valid_1's rmse: 0.179095
# [7200]	training's rmse: 0.171674	valid_1's rmse: 0.179084
# [7300]	training's rmse: 0.171566	valid_1's rmse: 0.179077
# [7400]	training's rmse: 0.171458	valid_1's rmse: 0.179069
# [7500]	training's rmse: 0.171346	valid_1's rmse: 0.179061
# [7600]	training's rmse: 0.171239	valid_1's rmse: 0.179052
# [7700]	training's rmse: 0.171133	valid_1's rmse: 0.179046
# [7800]	training's rmse: 0.171024	valid_1's rmse: 0.179045
# [7900]	training's rmse: 0.170921	valid_1's rmse: 0.179041
# [8000]	training's rmse: 0.170817	valid_1's rmse: 0.179033
# [8100]	training's rmse: 0.17071	valid_1's rmse: 0.179024
# [8200]	training's rmse: 0.170611	valid_1's rmse: 0.179021
# [8300]	training's rmse: 0.170503	valid_1's rmse: 0.179009
# [8400]	training's rmse: 0.1704	valid_1's rmse: 0.179005
# [8500]	training's rmse: 0.170293	valid_1's rmse: 0.178994
# [8600]	training's rmse: 0.17019	valid_1's rmse: 0.17899
# [8700]	training's rmse: 0.170084	valid_1's rmse: 0.178981
# [8800]	training's rmse: 0.169981	valid_1's rmse: 0.178975
# [8900]	training's rmse: 0.169877	valid_1's rmse: 0.178972
# [9000]	training's rmse: 0.169774	valid_1's rmse: 0.178966
# [9100]	training's rmse: 0.169677	valid_1's rmse: 0.178959
# [9200]	training's rmse: 0.169571	valid_1's rmse: 0.178951
# [9300]	training's rmse: 0.169467	valid_1's rmse: 0.178942
# [9400]	training's rmse: 0.169366	valid_1's rmse: 0.178938
# [9500]	training's rmse: 0.169263	valid_1's rmse: 0.178929
# [9600]	training's rmse: 0.169165	valid_1's rmse: 0.178926
# [9700]	training's rmse: 0.169066	valid_1's rmse: 0.178921
# [9800]	training's rmse: 0.168968	valid_1's rmse: 0.178914
# [9900]	training's rmse: 0.168871	valid_1's rmse: 0.178908
# [10000]	training's rmse: 0.168768	valid_1's rmse: 0.178899
# [10100]	training's rmse: 0.168672	valid_1's rmse: 0.178893
# [10200]	training's rmse: 0.168571	valid_1's rmse: 0.178891
# [10300]	training's rmse: 0.168471	valid_1's rmse: 0.178884
# [10400]	training's rmse: 0.168378	valid_1's rmse: 0.178883
# [10500]	training's rmse: 0.16828	valid_1's rmse: 0.178876
# [10600]	training's rmse: 0.168182	valid_1's rmse: 0.178873
# [10700]	training's rmse: 0.168084	valid_1's rmse: 0.178863
# [10800]	training's rmse: 0.167988	valid_1's rmse: 0.178858
# [10900]	training's rmse: 0.167891	valid_1's rmse: 0.178854
# [11000]	training's rmse: 0.167795	valid_1's rmse: 0.178851
# [11100]	training's rmse: 0.1677	valid_1's rmse: 0.178842
# [11200]	training's rmse: 0.167604	valid_1's rmse: 0.178834
# [11300]	training's rmse: 0.167511	valid_1's rmse: 0.178833
# [11400]	training's rmse: 0.167417	valid_1's rmse: 0.178831
# [11500]	training's rmse: 0.167322	valid_1's rmse: 0.178825
# [11600]	training's rmse: 0.16723	valid_1's rmse: 0.178825
# [11700]	training's rmse: 0.167139	valid_1's rmse: 0.178823
# [11800]	training's rmse: 0.167048	valid_1's rmse: 0.178817
# [11900]	training's rmse: 0.166958	valid_1's rmse: 0.178815
# Early stopping, best iteration is:
# [11865]	training's rmse: 0.166988	valid_1's rmse: 0.178814

# %%
feature_importance_df = pd.DataFrame()
feature_importance_df["feature"] = features
feature_importance_df["importance"] = lgb_model.feature_importance()
feature_importance_df.sort_values('importance')
# Out:
#                feature  importance
# 49         next_no_4.0         429
# 19           link_no_3         544
# 18           link_no_2         544
# 20           link_no_4         561
# 82             weekday         739
# 16           link_no_0         913
# 30     link_time_avg_4         933
# 25     link_time_sum_4         986
# 24     link_time_sum_3         987
# 35     link_time_std_4        1044
# 34     link_time_std_3        1089
# 39     link_time_max_3        1106
# 95   link_time_ratio_4        1185
# 93   link_time_ratio_3        1202
# 40     link_time_max_4        1215
# 70            cross_no        1239
# 23     link_time_sum_2        1245
# 29     link_time_avg_3        1256
# 38     link_time_max_2        1321
# 45     link_time_min_4        1409
# 61   next_time_std_4.0        1431
# 94        link_ratio_4        1472
# 33     link_time_std_2        1482
# 91   link_time_ratio_2        1497
# 48         next_no_3.0        1508
# 21     link_time_sum_0        1531
# 28     link_time_avg_2        1546
# 92        link_ratio_3        1581
# 53   next_time_sum_4.0        1642
# 65   next_time_max_4.0        1753
# 36     link_time_max_0        1753
# 87   link_time_ratio_0        1815
# 31     link_time_std_0        1819
# 57   next_time_avg_4.0        1830
# 90        link_ratio_2        1865
# 44     link_time_min_3        1888
# 103  next_time_ratio_4        1900
# 26     link_time_avg_0        1927
# 86        link_ratio_0        2175
# 85      log_simple_eta        2218
# 43     link_time_min_2        2385
# 2           simple_eta        2443
# 102       next_ratio_4        2681
# 84        log_distance        2733
# 1             distance        2869
# 17           link_no_1        2873
# 88        link_ratio_1        2879
# 46         next_no_1.0        2909
# 41     link_time_min_0        2921
# 47         next_no_2.0        3121
# 69   next_time_min_4.0        3132
# 9           old_driver        3218
# 10             link_no        3316
# 22     link_time_sum_1        3480
# 52   next_time_sum_3.0        3682
# 8               volume        3709
# 78    link_status_no_2        3736
# 13       link_time_std        3753
# 79    link_status_no_3        3800
# 60   next_time_std_3.0        3893
# 89   link_time_ratio_1        3907
# 101  next_time_ratio_3        3929
# 80    link_status_no_4        3981
# 64   next_time_max_3.0        3999
# 81            day_bias        4004
# 50   next_time_sum_1.0        4033
# 12       link_time_avg        4179
# 11       link_time_sum        4241
# 77    link_status_no_1        4281
# 4            speed_avg        4339
# 32     link_time_std_1        4364
# 51   next_time_sum_2.0        4440
# 100       next_ratio_3        4559
# 76    link_status_no_0        4623
# 14       link_time_max        4696
# 42     link_time_min_1        4773
# 56   next_time_avg_3.0        4778
# 37     link_time_max_1        4822
# 75           cross_min        4855
# 15       link_time_min        4877
# 27     link_time_avg_1        4904
# 97   next_time_ratio_1        4928
# 59   next_time_std_2.0        4938
# 74           cross_max        4986
# 5            speed_std        4993
# 6            speed_min        5087
# 58   next_time_std_1.0        5091
# 7            speed_max        5315
# 63   next_time_max_2.0        5345
# 55   next_time_avg_2.0        5488
# 62   next_time_max_1.0        5518
# 54   next_time_avg_1.0        5563
# 96        next_ratio_1        5666
# 99   next_time_ratio_2        5727
# 73           cross_std        6376
# 71           cross_sum        6383
# 72           cross_avg        6657
# 98        next_ratio_2        6927
# 68   next_time_min_3.0        7097
# 67   next_time_min_2.0        7615
# 3                speed        8027
# 66   next_time_min_1.0        8125
# 83         link_length        9242
# 0             slice_id       10159

# %%
pred_y = lgb_model.predict(test_x, num_iteration=lgb_model.best_iteration)

# result_lgb = (pred_proba>thresholds[ix]).astype('int')

# %%
submit = pd.DataFrame(columns=['id','result'])
submit['id'] = test['order_id']
submit['result'] = np.exp(pred_y).astype('int')

# %%
submit.to_csv('submission.csv',index=False)

# %%
plt.bar(feature_importance_df['feature'],feature_importance_df['importance'])
